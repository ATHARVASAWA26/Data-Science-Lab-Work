# %%
pip install pandas

# %%
import numpy as np
import pandas as pd

import warnings

warnings.filterwarnings('ignore')

# %%
a = np.array([10, 11, "aa", "bb", 45, 88])
a.dtype
print(a)
# Out:
# ['10' '11' 'aa' 'bb' '45' '88']

# %%
S = pd.Series(a, index=list(range(10, 16)))
S
# Out:
# 10    10
# 11    11
# 12    aa
# 13    bb
# 14    45
# 15    88
# dtype: object

# %%
S.loc[10:15]
# Out:
# 10    10
# 11    11
# 12    aa
# 13    bb
# 14    45
# 15    88
# dtype: object

# %%
lt=[10, 11, "aa", "bb", 45, 88]

# %%
mydic={"Snake":0, "Leapord":2, "Cow":5, "Human": 8}
myD=pd.Series(mydic)
myD
# Out:
# Snake      0
# Leapord    2
# Cow        5
# Human      8
# dtype: int64

# %%
s=pd.Series(100, index = list(range(5,10)))
s
# Out:
# 5    100
# 6    100
# 7    100
# 8    100
# 9    100
# dtype: int64

# %%
THARVAdf=pd.read_excel("/content/German-Credit_1.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_12870/2674546771.py in <cell line: 0>()
# ----> 1 THARVAdf=pd.read_excel("/content/German-Credit_1.xls")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
THARVAdf=pd.read_excel("/content/German-Credit_1.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_12870/2674546771.py in <cell line: 0>()
# ----> 1 THARVAdf=pd.read_excel("/content/German-Credit_1.xls")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
df.head()

# %%
df.tail(5)

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df_sub = df["EDUCATION"]
df_sub.head()

# %%
df.mean()

# %%
df.std()

# %%
df.describe(include = "all")

# %%
df.loc[1:5,"NEW_CAR":"AMOUNT"]

# %%
df.iloc[1:5,2:9]

# %%
mean_AMOUNT = df["AMOUNT"].mean()
print(mean_AMOUNT)
